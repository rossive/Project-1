# %%
#loading libraries

import pandas as pd
import numpy as np

# %%
#loading csv file

location = "datasets/DC_Properties.csv"
df = pd.read_csv(location)

# %% [markdown]
# # Getting to know the Data

# %%
df.describe()
# Out:
#           Unnamed: 0         BATHRM      HF_BATHRM      NUM_UNITS  \
# count  158957.000000  158957.000000  158957.000000  106696.000000
# mean    79478.000000       1.810678       0.458237       1.198039
# std     45887.077707       0.976396       0.587571       0.596924
# min         0.000000       0.000000       0.000000       0.000000
# 25%     39739.000000       1.000000       0.000000       1.000000
# 50%     79478.000000       2.000000       0.000000       1.000000
# 75%    119217.000000       2.000000       1.000000       1.000000
# max    158956.000000      14.000000      11.000000       6.000000
#
#                ROOMS          BEDRM            AYB       YR_RMDL  \
# count  158957.000000  158957.000000  158686.000000  80928.000000
# mean        6.187736       2.732506    1941.987579   1998.243537
# std         2.618165       1.358864      33.640234     16.575786
# min         0.000000       0.000000    1754.000000     20.000000
# ...

# %%
df.count()
# Out:
# Unnamed: 0            158957
# BATHRM                158957
# HF_BATHRM             158957
# HEAT                  158957
# AC                    158957
# NUM_UNITS             106696
# ROOMS                 158957
# BEDRM                 158957
# AYB                   158686
# YR_RMDL                80928
# EYB                   158957
# STORIES               106652
# SALEDATE              132187
# PRICE                  98216
# QUALIFIED             158957
# SALE_NUM              158957
# GBA                   106696
# BLDG_NUM              158957
# STYLE                 106696
# STRUCT                106696
# GRADE                 106696
# CNDTN                 106696
# EXTWALL               106696
# ROOF                  106696
# INTWALL               106696
# KITCHENS              106695
# FIREPLACES            158957
# USECODE               158957
# LANDAREA              158957
# GIS_LAST_MOD_DTTM     158957
# SOURCE                158957
# CMPLX_NUM              52261
# ...

# %%
df.head(1000)
# Out:
#      Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0             0       4          0      Warm Cool  Y        2.0      8      4
# 1             1       3          1      Warm Cool  Y        2.0     11      5
# 2             2       3          1  Hot Water Rad  Y        2.0      9      5
# 3             3       3          1  Hot Water Rad  Y        2.0      8      5
# 4             4       2          1      Warm Cool  Y        1.0     11      3
# 5             5       3          2  Hot Water Rad  Y        1.0     10      5
# 6             6       1          0      Warm Cool  Y        2.0      5      2
# 7             7       3          1  Hot Water Rad  Y        2.0      8      4
# 8             8       3          1      Warm Cool  Y        2.0      7      3
# 9             9       1          1  Hot Water Rad  Y        1.0      6      2
# 10           10       3          0     Forced Air  N        3.0     12      5
# ...

# %%
#Cleaning duplicates

nodupedf = df.drop_duplicates()
nodupedf.count()

#no duplicate rows found
# Out:
# Unnamed: 0            158957
# BATHRM                158957
# HF_BATHRM             158957
# HEAT                  158957
# AC                    158957
# NUM_UNITS             106696
# ROOMS                 158957
# BEDRM                 158957
# AYB                   158686
# YR_RMDL                80928
# EYB                   158957
# STORIES               106652
# SALEDATE              132187
# PRICE                  98216
# QUALIFIED             158957
# SALE_NUM              158957
# GBA                   106696
# BLDG_NUM              158957
# STYLE                 106696
# STRUCT                106696
# GRADE                 106696
# CNDTN                 106696
# EXTWALL               106696
# ROOF                  106696
# INTWALL               106696
# KITCHENS              106695
# FIREPLACES            158957
# USECODE               158957
# LANDAREA              158957
# GIS_LAST_MOD_DTTM     158957
# SOURCE                158957
# CMPLX_NUM              52261
# ...

# %%
#Drop rows without Sale Price data
df_sale_price = df.dropna(subset=['PRICE'])

# %%
#Segmenting by City Quadrant

pd.value_counts(df_sale_price['QUADRANT'])
# Out:
# NW    57733
# NE    21774
# SE    15857
# SW     2751
# Name: QUADRANT, dtype: int64

# %%
#Segmenting by City Quadrant

pd.value_counts(df_sale_price['SOURCE'])
# Out:
# Residential    57900
# Condominium    40316
# Name: SOURCE, dtype: int64

# %%
df_sale_price.groupby('QUADRANT')['PRICE'].mean()
#Average price per city quadrant
# Out:
# QUADRANT
# NE    3.928715e+05
# NW    1.317785e+06
# SE    3.682260e+05
# SW    3.470489e+05
# Name: PRICE, dtype: float64

# %%
df_sale_price.groupby('QUADRANT')['STORIES'].mean()
# Out:
# QUADRANT
# NE    2.065751
# NW    2.197849
# SE    2.043064
# SW    2.153082
# Name: STORIES, dtype: float64

# %%
df_sale_price.groupby('QUADRANT')['PRICE'].max()
# Out:
# QUADRANT
# NE      7576980.0
# NW    137427545.0
# SE     25100000.0
# SW     11000000.0
# Name: PRICE, dtype: float64

# %%
df_sale_price[['PRICE','BEDRM','BATHRM','SQUARE']].describe()
# Out:
#               PRICE         BEDRM        BATHRM
# count  9.821600e+04  98216.000000  98216.000000
# mean   9.313516e+05      2.606480      1.859157
# std    7.061325e+06      1.393801      0.978321
# min    1.000000e+00      0.000000      0.000000
# 25%    2.400000e+05      2.000000      1.000000
# 50%    3.999990e+05      3.000000      2.000000
# 75%    6.520000e+05      3.000000      2.000000
# max    1.374275e+08     20.000000     12.000000
